# %%
import streamlit as st
import numpy as np 
import matplotlib.pyplot as plt 
from sklearn.datasets import load_iris 
from sklearn.linear_model import LogisticRegression

# %%
iris = load_iris()
X, y = iris.data, iris.target

# %%
model = LogisticRegression(max_iter=200)
model.fit(X, y)
# Out:
# LogisticRegression(max_iter=200)

# %%
st.title('Iris Species Prediction')
# Out:
# 2025-04-19 20:31:56.181 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-19 20:31:56.183 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
def user_input_features():
    sepal_length = st.sidebar.slider('Sepal Length', 4.3, 7.9, 5.4)
    sepal_width = st.sidebar.slider('Sepal Width', 2.0, 4.4, 3.4)
    petal_length = st.sidebar.slider('Petal Length', 1.0, 6.9, 4.1)
    petal_width = st.sidebar.slider('Petal Width', 0.1, 2.5, 1.3)
    return np.array([sepal_length, sepal_width, petal_length, petal_width]).reshape(1, -1)

input_df = user_input_features()
# Out:
# 2025-04-19 20:31:58.121 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-19 20:31:58.125 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-19 20:31:58.125 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-19 20:31:58.126 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-19 20:31:58.127 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-19 20:31:58.128 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-19 20:31:58.129 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-19 20:31:58.129 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-19 20:31:58.130 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-19 20:31:58.131 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-19 20:31:58.132 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-19 20:31:58.132 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-19 20:31:58.133 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-19 20:31:58.134 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-19 20:31:58.134 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-19 20:31:58.135 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-19 20:31:58.136 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-19 20:31:58.136 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-19 20:31:58.137 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-19 20:31:58.137 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
st.subheader('User Input Features')
st.write(input_df)
# Out:
# 2025-04-19 20:32:01.362 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-19 20:32:01.363 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-19 20:32:01.366 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-19 20:32:01.366 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
prediction = model.predict(input_df)
prediction_proba = model.predict_proba(input_df)

# %%
st.subheader('Prediction')
st.write(iris.target_names[prediction][0])
st.subheader('Prediction Probability')
st.bar_chart(prediction_proba.flatten())
# Out:
# 2025-04-19 20:32:05.842 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-19 20:32:05.843 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-19 20:32:05.845 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-19 20:32:05.845 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-19 20:32:05.846 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-19 20:32:05.847 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-19 20:32:05.848 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-19 20:32:05.848 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-19 20:32:05.860 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-19 20:32:05.860 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
fig, ax = plt.subplots()
colors = ['red', 'green', 'blue']
for i in range(len(iris.target_names)): 
    ax.scatter(X[y == i, 0], X[y == i, 1], c=colors[i], label=iris.target_names[i])
ax.set_xlabel('Sepal Length')
ax.set_ylabel('Sepal Width')
ax.legend()
st.pyplot(fig)
# Out:
# 2025-04-19 20:32:08.225 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-19 20:32:08.378 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-19 20:32:08.378 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
fig2, ax2 = plt.subplots()

for i in range(len(iris.target_names)): 
    ax2.scatter(X[y == i, 2], X[y == i, 3], c=colors[i], label=iris.target_names[i])
ax2.set_xlabel('Petal Length')
ax2.set_ylabel('Petal Width')
ax2.legend()

# %%
ax2.scatter(input_df[0,2], input_df[0,3], c='black', s=200, alpha=0.5, label='Your Input')
ax2.legend()
st.pyplot(fig2)
# Out:
# 2025-04-19 20:32:14.150 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-19 20:32:14.317 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-19 20:32:14.317 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()
